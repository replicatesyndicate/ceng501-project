# %%
FNAME = "minigrid_empty_16x16_plain_dqn_1"
import numpy as np

import torch
import torch.nn as nn

from stable_baselines3 import DQN
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.evaluation import evaluate_policy

import gymnasium as gym
import minigrid
from minigrid.wrappers import ImgObsWrapper

from IPython import display

# %%
class MinigridFeaturesExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.Space, features_dim: int = 512, normalized_image: bool = False) -> None:
        super().__init__(observation_space, features_dim)
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 16, (2, 2)),
            nn.ReLU(),
            nn.Conv2d(16, 32, (2, 2)),
            nn.ReLU(),
            nn.Conv2d(32, 64, (2, 2)),
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))

# %%
policy_kwargs = dict(
    features_extractor_class=MinigridFeaturesExtractor,
    features_extractor_kwargs=dict(features_dim=128),
)

env = gym.make("MiniGrid-Empty-5x5-v0", render_mode="rgb_array")
env = ImgObsWrapper(env)

# %%
model = DQN("CnnPolicy", env, policy_kwargs=policy_kwargs, verbose=1, tensorboard_log="./dqn_minigrid_logs")
model.learn(2e5)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.5     |
# |    ep_rew_mean      | 0.379    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 641      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 254      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00671  |
# |    n_updates        | 38       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.9     |
# |    ep_rew_mean      | 0.391    |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 830      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 519      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.012    |
# |    n_updates        | 104      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.6     |
# |    ep_rew_mean      | 0.261    |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 951      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 919      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.47e-05 |
# |    n_updates        | 204      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.4     |
# |    ep_rew_mean      | 0.295    |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1001     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1175     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.76e-05 |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76       |
# |    ep_rew_mean      | 0.271    |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1027     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1521     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000402 |
# |    n_updates        | 355      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.8     |
# |    ep_rew_mean      | 0.249    |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1054     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1868     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.24e-05 |
# |    n_updates        | 441      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.2     |
# |    ep_rew_mean      | 0.289    |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1065     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2079     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.31e-05 |
# |    n_updates        | 494      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.5     |
# |    ep_rew_mean      | 0.346    |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1065     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2193     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.96e-06 |
# |    n_updates        | 523      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69       |
# |    ep_rew_mean      | 0.34     |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1077     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2484     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.93e-05 |
# |    n_updates        | 595      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.8     |
# |    ep_rew_mean      | 0.329    |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1089     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2792     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.41e-05 |
# |    n_updates        | 672      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.8     |
# |    ep_rew_mean      | 0.34     |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1096     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3029     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000132 |
# |    n_updates        | 732      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.9     |
# |    ep_rew_mean      | 0.35     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1100     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3257     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.68e-05 |
# |    n_updates        | 789      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.6     |
# |    ep_rew_mean      | 0.331    |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1106     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3619     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.3e-05  |
# |    n_updates        | 879      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.3     |
# |    ep_rew_mean      | 0.333    |
# |    exploration_rate | 0.816    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1109     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3882     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.52e-05 |
# |    n_updates        | 945      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68       |
# |    ep_rew_mean      | 0.346    |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1110     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4079     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00364  |
# |    n_updates        | 994      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.3     |
# |    ep_rew_mean      | 0.345    |
# |    exploration_rate | 0.792    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1109     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4370     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.4e-05  |
# |    n_updates        | 1067     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.2     |
# |    ep_rew_mean      | 0.357    |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1106     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4569     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.5e-05  |
# |    n_updates        | 1117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.1     |
# |    ep_rew_mean      | 0.36     |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1106     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4832     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.08e-05 |
# |    n_updates        | 1182     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.2     |
# |    ep_rew_mean      | 0.37     |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1105     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5030     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.9e-05  |
# |    n_updates        | 1232     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.4     |
# |    ep_rew_mean      | 0.378    |
# |    exploration_rate | 0.752    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1107     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5230     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.52e-05 |
# |    n_updates        | 1282     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.3     |
# |    ep_rew_mean      | 0.369    |
# |    exploration_rate | 0.735    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1103     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5570     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.68e-05 |
# |    n_updates        | 1367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.5     |
# |    ep_rew_mean      | 0.366    |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1103     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5852     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00194  |
# |    n_updates        | 1437     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.5     |
# |    ep_rew_mean      | 0.365    |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1101     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6120     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.57e-05 |
# |    n_updates        | 1504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.9     |
# |    ep_rew_mean      | 0.362    |
# |    exploration_rate | 0.695    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1100     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6420     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.14e-05 |
# |    n_updates        | 1579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66       |
# |    ep_rew_mean      | 0.371    |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1099     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6601     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00538  |
# |    n_updates        | 1625     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66       |
# |    ep_rew_mean      | 0.372    |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1096     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6854     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.71e-05 |
# |    n_updates        | 1688     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.7     |
# |    ep_rew_mean      | 0.363    |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1094     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 7193     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.35e-05 |
# |    n_updates        | 1773     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.9     |
# |    ep_rew_mean      | 0.393    |
# |    exploration_rate | 0.653    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1093     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 7307     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.89e-05 |
# |    n_updates        | 1801     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.7     |
# |    ep_rew_mean      | 0.395    |
# |    exploration_rate | 0.642    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1089     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 7547     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.34e-06 |
# |    n_updates        | 1861     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.8     |
# |    ep_rew_mean      | 0.404    |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1087     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7802     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0017   |
# |    n_updates        | 1925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.3     |
# |    ep_rew_mean      | 0.419    |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1085     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.17e-05 |
# |    n_updates        | 1974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62       |
# |    ep_rew_mean      | 0.411    |
# |    exploration_rate | 0.607    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1081     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 8275     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00643  |
# |    n_updates        | 2043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.1     |
# |    ep_rew_mean      | 0.41     |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1080     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 8401     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00206  |
# |    n_updates        | 2075     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.6     |
# |    ep_rew_mean      | 0.414    |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1076     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8648     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000144 |
# |    n_updates        | 2136     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.4     |
# |    ep_rew_mean      | 0.428    |
# |    exploration_rate | 0.581    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1074     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8831     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 2182     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 59.9     |
# |    ep_rew_mean      | 0.433    |
# |    exploration_rate | 0.572    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1070     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 9021     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.78e-05 |
# |    n_updates        | 2230     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 59.7     |
# |    ep_rew_mean      | 0.435    |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1067     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 9227     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.07e-05 |
# |    n_updates        | 2281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.2     |
# |    ep_rew_mean      | 0.45     |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1064     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 9438     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.77e-05 |
# |    n_updates        | 2334     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.5     |
# |    ep_rew_mean      | 0.457    |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1061     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9632     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.45e-06 |
# |    n_updates        | 2382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.9     |
# |    ep_rew_mean      | 0.455    |
# |    exploration_rate | 0.531    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1058     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9864     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.76e-05 |
# |    n_updates        | 2440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.3     |
# |    ep_rew_mean      | 0.459    |
# |    exploration_rate | 0.52     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1055     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 10100    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.62e-05 |
# |    n_updates        | 2499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.1     |
# |    ep_rew_mean      | 0.451    |
# |    exploration_rate | 0.507    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1053     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 10383    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00343  |
# |    n_updates        | 2570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.2     |
# |    ep_rew_mean      | 0.449    |
# |    exploration_rate | 0.494    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1051     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10656    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.16e-05 |
# |    n_updates        | 2638     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.1     |
# |    ep_rew_mean      | 0.449    |
# |    exploration_rate | 0.485    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1048     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10842    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.4e-05  |
# |    n_updates        | 2685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.1     |
# |    ep_rew_mean      | 0.45     |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1046     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 11037    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00262  |
# |    n_updates        | 2734     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57       |
# |    ep_rew_mean      | 0.461    |
# |    exploration_rate | 0.465    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1044     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 11267    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.71e-05 |
# |    n_updates        | 2791     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.8     |
# |    ep_rew_mean      | 0.464    |
# |    exploration_rate | 0.452    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1041     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11533    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000103 |
# |    n_updates        | 2858     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.6     |
# |    ep_rew_mean      | 0.476    |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1039     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11685    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.93e-05 |
# |    n_updates        | 2896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.9     |
# |    ep_rew_mean      | 0.485    |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1037     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11906    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.63e-06 |
# |    n_updates        | 2951     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.4     |
# |    ep_rew_mean      | 0.49     |
# |    exploration_rate | 0.428    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1036     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 12036    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5e-05    |
# |    n_updates        | 2983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.1     |
# |    ep_rew_mean      | 0.491    |
# |    exploration_rate | 0.417    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1033     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 12268    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.46e-05 |
# |    n_updates        | 3041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.7     |
# |    ep_rew_mean      | 0.515    |
# |    exploration_rate | 0.413    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1032     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 12364    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.51e-05 |
# |    n_updates        | 3065     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.3     |
# |    ep_rew_mean      | 0.499    |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1027     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12633    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00795  |
# |    n_updates        | 3133     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.2     |
# |    ep_rew_mean      | 0.509    |
# |    exploration_rate | 0.394    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1025     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12765    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.05e-05 |
# |    n_updates        | 3166     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.5     |
# |    ep_rew_mean      | 0.507    |
# |    exploration_rate | 0.38     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1021     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 13052    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00108  |
# |    n_updates        | 3237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.6     |
# |    ep_rew_mean      | 0.505    |
# |    exploration_rate | 0.37     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1018     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13264    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.94e-05 |
# |    n_updates        | 3290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.1     |
# |    ep_rew_mean      | 0.501    |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1013     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13583    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.91e-05 |
# |    n_updates        | 3370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.1     |
# |    ep_rew_mean      | 0.49     |
# |    exploration_rate | 0.344    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1011     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13812    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.21e-05 |
# |    n_updates        | 3427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54       |
# |    ep_rew_mean      | 0.492    |
# |    exploration_rate | 0.333    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1008     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 14043    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.31e-05 |
# |    n_updates        | 3485     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55       |
# |    ep_rew_mean      | 0.481    |
# |    exploration_rate | 0.319    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1004     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14334    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00991  |
# |    n_updates        | 3558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.2     |
# |    ep_rew_mean      | 0.489    |
# |    exploration_rate | 0.314    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1002     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14444    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.48e-05 |
# |    n_updates        | 3585     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.4     |
# |    ep_rew_mean      | 0.496    |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1000     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14571    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00506  |
# |    n_updates        | 3617     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.8     |
# |    ep_rew_mean      | 0.492    |
# |    exploration_rate | 0.296    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 997      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14820    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00818  |
# |    n_updates        | 3679     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.2     |
# |    ep_rew_mean      | 0.48     |
# |    exploration_rate | 0.28     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 993      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 15151    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00192  |
# |    n_updates        | 3762     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.7     |
# |    ep_rew_mean      | 0.484    |
# |    exploration_rate | 0.272    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 991      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 15330    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0164   |
# |    n_updates        | 3807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.7     |
# |    ep_rew_mean      | 0.503    |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 991      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 15373    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000116 |
# |    n_updates        | 3818     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.8     |
# |    ep_rew_mean      | 0.512    |
# |    exploration_rate | 0.261    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 988      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 15558    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00612  |
# |    n_updates        | 3864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52       |
# |    ep_rew_mean      | 0.51     |
# |    exploration_rate | 0.247    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 984      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 15855    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.29e-05 |
# |    n_updates        | 3938     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.1     |
# |    ep_rew_mean      | 0.519    |
# |    exploration_rate | 0.242    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 983      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 15948    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.55e-05 |
# |    n_updates        | 3961     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.7     |
# |    ep_rew_mean      | 0.514    |
# |    exploration_rate | 0.23     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 980      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 16208    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.38e-05 |
# |    n_updates        | 4026     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.7     |
# |    ep_rew_mean      | 0.513    |
# |    exploration_rate | 0.219    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 978      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 16438    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00123  |
# |    n_updates        | 4084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.8     |
# |    ep_rew_mean      | 0.522    |
# |    exploration_rate | 0.211    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 975      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 16612    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.54e-05 |
# |    n_updates        | 4127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.1     |
# |    ep_rew_mean      | 0.508    |
# |    exploration_rate | 0.198    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 972      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 16893    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.87e-05 |
# |    n_updates        | 4198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.5     |
# |    ep_rew_mean      | 0.503    |
# |    exploration_rate | 0.185    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 969      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 17151    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.82e-05 |
# |    n_updates        | 4262     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.3     |
# |    ep_rew_mean      | 0.494    |
# |    exploration_rate | 0.175    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 967      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 17370    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00477  |
# |    n_updates        | 4317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.3     |
# |    ep_rew_mean      | 0.495    |
# |    exploration_rate | 0.164    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 965      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 17594    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.87e-05 |
# |    n_updates        | 4373     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.3     |
# |    ep_rew_mean      | 0.474    |
# |    exploration_rate | 0.15     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 962      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 17892    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.01e-05 |
# |    n_updates        | 4447     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.5     |
# |    ep_rew_mean      | 0.482    |
# |    exploration_rate | 0.141    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 960      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 18085    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.77e-06 |
# |    n_updates        | 4496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.1     |
# |    ep_rew_mean      | 0.477    |
# |    exploration_rate | 0.132    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 958      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 18278    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19e-05 |
# |    n_updates        | 4544     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.9     |
# |    ep_rew_mean      | 0.468    |
# |    exploration_rate | 0.114    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 954      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 18646    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46e-05 |
# |    n_updates        | 4636     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57       |
# |    ep_rew_mean      | 0.456    |
# |    exploration_rate | 0.0994   |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 951      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 18960    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00576  |
# |    n_updates        | 4714     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.6     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.0859   |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 949      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 19244    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00413  |
# |    n_updates        | 4785     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57       |
# |    ep_rew_mean      | 0.456    |
# |    exploration_rate | 0.0734   |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 946      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 19508    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.77e-05 |
# |    n_updates        | 4851     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.4     |
# |    ep_rew_mean      | 0.451    |
# |    exploration_rate | 0.0602   |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 944      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 19786    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.95e-05 |
# |    n_updates        | 4921     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.4     |
# |    ep_rew_mean      | 0.442    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 941      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 20173    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00495  |
# |    n_updates        | 5018     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.4     |
# |    ep_rew_mean      | 0.421    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 938      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 20487    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.15e-05 |
# |    n_updates        | 5096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.4     |
# |    ep_rew_mean      | 0.401    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 936      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 20810    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2e-05    |
# |    n_updates        | 5177     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.1     |
# |    ep_rew_mean      | 0.394    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 933      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 21131    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.52e-05 |
# |    n_updates        | 5257     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.3     |
# |    ep_rew_mean      | 0.389    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 931      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 21482    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00409  |
# |    n_updates        | 5345     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.5     |
# |    ep_rew_mean      | 0.366    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 927      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 21882    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.72e-05 |
# |    n_updates        | 5445     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68       |
# |    ep_rew_mean      | 0.342    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 925      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 22168    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.7e-06  |
# |    n_updates        | 5516     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    time_elapsed     | 237      |
# |    total_timesteps  | 187790   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.96e-05 |
# |    n_updates        | 46922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3756     |
# |    fps              | 789      |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 188190   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.66e-06 |
# |    n_updates        | 47022    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3760     |
# |    fps              | 789      |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 188590   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18e-05 |
# |    n_updates        | 47122    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3764     |
# |    fps              | 789      |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 188990   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13e-05 |
# |    n_updates        | 47222    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3768     |
# |    fps              | 789      |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 189390   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000147 |
# |    n_updates        | 47322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3772     |
# |    fps              | 789      |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 189790   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.63e-05 |
# |    n_updates        | 47422    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3776     |
# |    fps              | 789      |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 190190   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.04e-05 |
# |    n_updates        | 47522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3780     |
# |    fps              | 789      |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 190590   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000386 |
# |    n_updates        | 47622    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3784     |
# |    fps              | 789      |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 190990   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000171 |
# |    n_updates        | 47722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3788     |
# |    fps              | 789      |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 191390   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00147  |
# |    n_updates        | 47822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3792     |
# |    fps              | 789      |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 191790   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.64e-06 |
# |    n_updates        | 47922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3796     |
# |    fps              | 789      |
# |    time_elapsed     | 243      |
# |    total_timesteps  | 192190   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.34e-05 |
# |    n_updates        | 48022    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3800     |
# |    fps              | 789      |
# |    time_elapsed     | 243      |
# |    total_timesteps  | 192590   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.73e-05 |
# |    n_updates        | 48122    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3804     |
# |    fps              | 789      |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 192990   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.01e-05 |
# |    n_updates        | 48222    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3808     |
# |    fps              | 789      |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 193390   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.29e-05 |
# |    n_updates        | 48322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3812     |
# |    fps              | 789      |
# |    time_elapsed     | 245      |
# |    total_timesteps  | 193790   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.98e-05 |
# |    n_updates        | 48422    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3816     |
# |    fps              | 789      |
# |    time_elapsed     | 245      |
# |    total_timesteps  | 194190   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.59e-05 |
# |    n_updates        | 48522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3820     |
# |    fps              | 789      |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 194590   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.57e-06 |
# |    n_updates        | 48622    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3824     |
# |    fps              | 789      |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 194990   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.92e-05 |
# |    n_updates        | 48722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3828     |
# |    fps              | 789      |
# |    time_elapsed     | 247      |
# |    total_timesteps  | 195390   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.09e-05 |
# |    n_updates        | 48822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3832     |
# |    fps              | 789      |
# |    time_elapsed     | 247      |
# |    total_timesteps  | 195790   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.73e-05 |
# |    n_updates        | 48922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3836     |
# |    fps              | 789      |
# |    time_elapsed     | 248      |
# |    total_timesteps  | 196190   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.99e-05 |
# |    n_updates        | 49022    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3840     |
# |    fps              | 789      |
# |    time_elapsed     | 248      |
# |    total_timesteps  | 196590   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000123 |
# |    n_updates        | 49122    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3844     |
# |    fps              | 789      |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 196990   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.29e-05 |
# |    n_updates        | 49222    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3848     |
# |    fps              | 789      |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 197390   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00017  |
# |    n_updates        | 49322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3852     |
# |    fps              | 789      |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 197790   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000105 |
# |    n_updates        | 49422    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3856     |
# |    fps              | 789      |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 198190   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.04e-05 |
# |    n_updates        | 49522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3860     |
# |    fps              | 789      |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 198590   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.46e-05 |
# |    n_updates        | 49622    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 789      |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 198990   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.26e-05 |
# |    n_updates        | 49722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 789      |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 199390   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.69e-06 |
# |    n_updates        | 49822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 789      |
# |    time_elapsed     | 253      |
# |    total_timesteps  | 199790   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.04e-05 |
# |    n_updates        | 49922    |
# ----------------------------------

# %%
# model = DQN.load(f"./models/{FNAME}", env= env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.save(f"./models/{FNAME}")

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")

print(f"mean_reward: {mean_reward}, std_reward:{std_reward}")
# Out:
# /home/kobot/.local/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward: 0.0, std_reward:0.0
