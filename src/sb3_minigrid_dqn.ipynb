# %%
import numpy as np

import torch
import torch.nn as nn

from stable_baselines3 import DQN
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

import gymnasium as gym
import minigrid
from minigrid.wrappers import ImgObsWrapper

# %%
class MinigridFeaturesExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.Space, features_dim: int = 512, normalized_image: bool = False) -> None:
        super().__init__(observation_space, features_dim)
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 16, (2, 2)),
            nn.ReLU(),
            nn.Conv2d(16, 32, (2, 2)),
            nn.ReLU(),
            nn.Conv2d(32, 64, (2, 2)),
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))

# %%
policy_kwargs = dict(
    features_extractor_class=MinigridFeaturesExtractor,
    features_extractor_kwargs=dict(features_dim=128),
)

env = gym.make("MiniGrid-Empty-16x16-v0", render_mode="rgb_array")
env = ImgObsWrapper(env)

model = DQN("CnnPolicy", env, policy_kwargs=policy_kwargs, verbose=1)
model.learn(2e5)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02e+03 |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1076     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4096     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.68e-10 |
# |    n_updates        | 998      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02e+03 |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.611    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1075     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 8192     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.08e-10 |
# |    n_updates        | 2022     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 949      |
# |    ep_rew_mean      | 0.0741   |
# |    exploration_rate | 0.459    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1037     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 11390    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.88e-10 |
# |    n_updates        | 2822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 968      |
# |    ep_rew_mean      | 0.0556   |
# |    exploration_rate | 0.264    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 988      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 15486    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19e-09 |
# |    n_updates        | 3846     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 979      |
# |    ep_rew_mean      | 0.0445   |
# |    exploration_rate | 0.0699   |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 947      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 19582    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.84e-10 |
# |    n_updates        | 4870     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 987      |
# |    ep_rew_mean      | 0.0371   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 918      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 23678    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.49e-09 |
# |    n_updates        | 5894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 992      |
# |    ep_rew_mean      | 0.0318   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 902      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 27774    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.7e-10  |
# |    n_updates        | 6918     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 996      |
# |    ep_rew_mean      | 0.0278   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 889      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 31870    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.74e-10 |
# |    n_updates        | 7942     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 980      |
# |    ep_rew_mean      | 0.0438   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 878      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 35297    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.56e-10 |
# |    n_updates        | 8799     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 985      |
# |    ep_rew_mean      | 0.0394   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 870      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 39393    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.22e-10 |
# |    n_updates        | 9823     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 988      |
# |    ep_rew_mean      | 0.0358   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 864      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 43489    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.71e-10 |
# |    n_updates        | 10847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 991      |
# |    ep_rew_mean      | 0.0329   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 859      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 47585    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02e-09 |
# |    n_updates        | 11871    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 994      |
# |    ep_rew_mean      | 0.0303   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 855      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 51681    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.27e-09 |
# |    n_updates        | 12895    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 991      |
# |    ep_rew_mean      | 0.034    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 848      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 55521    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.24e-07 |
# |    n_updates        | 13855    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 986      |
# |    ep_rew_mean      | 0.0398   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 845      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 59181    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.46e-10 |
# |    n_updates        | 14770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 974      |
# |    ep_rew_mean      | 0.0533   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 841      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 62335    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.83e-07 |
# |    n_updates        | 15558    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 963      |
# |    ep_rew_mean      | 0.0657   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 838      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 65462    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.82e-10 |
# |    n_updates        | 16340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 966      |
# |    ep_rew_mean      | 0.062    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 833      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 69558    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.19e-10 |
# |    n_updates        | 17364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 958      |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 831      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 72793    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.15e-10 |
# |    n_updates        | 18173    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 952      |
# |    ep_rew_mean      | 0.0773   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 828      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 76137    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.47e-10 |
# |    n_updates        | 19009    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 949      |
# |    ep_rew_mean      | 0.0806   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 825      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 79679    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.79e-07 |
# |    n_updates        | 19894    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 942      |
# |    ep_rew_mean      | 0.0866   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 823      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 82917    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.85e-10 |
# |    n_updates        | 20704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 943      |
# |    ep_rew_mean      | 0.0864   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 820      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 86755    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38e-07 |
# |    n_updates        | 21663    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 946      |
# |    ep_rew_mean      | 0.0828   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 818      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 90851    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.77e-10 |
# |    n_updates        | 22687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 949      |
# |    ep_rew_mean      | 0.0795   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 816      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 94947    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.19e-06 |
# |    n_updates        | 23711    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 946      |
# |    ep_rew_mean      | 0.0839   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 814      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 98661    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.42e-07 |
# |    n_updates        | 24640    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 935      |
# |    ep_rew_mean      | 0.0954   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 813      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 101677   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.3e-10  |
# |    n_updates        | 25394    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 933      |
# |    ep_rew_mean      | 0.0977   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 813      |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 104722   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.29e-09 |
# |    n_updates        | 26155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 929      |
# |    ep_rew_mean      | 0.104    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 811      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 108370   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.68e-05 |
# |    n_updates        | 27067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 905      |
# |    ep_rew_mean      | 0.127    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 810      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 110113   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.57e-06 |
# |    n_updates        | 27503    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 897      |
# |    ep_rew_mean      | 0.137    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 809      |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 113375   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.39e-10 |
# |    n_updates        | 28318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 884      |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 808      |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 116188   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.64e-06 |
# |    n_updates        | 29021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 870      |
# |    ep_rew_mean      | 0.165    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 808      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 118898   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.68e-10 |
# |    n_updates        | 29699    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 877      |
# |    ep_rew_mean      | 0.158    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 808      |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 122994   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.44e-07 |
# |    n_updates        | 30723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 863      |
# |    ep_rew_mean      | 0.173    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 807      |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 125648   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.13e-10 |
# |    n_updates        | 31386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 838      |
# |    ep_rew_mean      | 0.198    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 807      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 127262   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08e-09 |
# |    n_updates        | 31790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 832      |
# |    ep_rew_mean      | 0.204    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 806      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 130804   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.46e-09 |
# |    n_updates        | 32675    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 814      |
# |    ep_rew_mean      | 0.224    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 806      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 133052   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.58e-05 |
# |    n_updates        | 33237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 815      |
# |    ep_rew_mean      | 0.223    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 805      |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 137006   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.64e-06 |
# |    n_updates        | 34226    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 801      |
# |    ep_rew_mean      | 0.237    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 805      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 139269   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.84e-06 |
# |    n_updates        | 34792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 785      |
# |    ep_rew_mean      | 0.252    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 805      |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 140864   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21e-05 |
# |    n_updates        | 35190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 781      |
# |    ep_rew_mean      | 0.257    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 805      |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 143551   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.72e-06 |
# |    n_updates        | 35862    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 767      |
# |    ep_rew_mean      | 0.272    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 804      |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 146273   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.01e-06 |
# |    n_updates        | 36543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 758      |
# |    ep_rew_mean      | 0.282    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 804      |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 148641   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.77e-07 |
# |    n_updates        | 37135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 735      |
# |    ep_rew_mean      | 0.305    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 804      |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 149657   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.93e-09 |
# |    n_updates        | 37389    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 734      |
# |    ep_rew_mean      | 0.308    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 804      |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 153050   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.66e-09 |
# |    n_updates        | 38237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 738      |
# |    ep_rew_mean      | 0.305    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 804      |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 156678   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.59e-07 |
# |    n_updates        | 39144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 721      |
# |    ep_rew_mean      | 0.322    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 803      |
# |    time_elapsed     | 197      |
# |    total_timesteps  | 158830   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.06e-08 |
# |    n_updates        | 39682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 705      |
# |    ep_rew_mean      | 0.339    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 803      |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 161326   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.87e-09 |
# |    n_updates        | 40306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 683      |
# |    ep_rew_mean      | 0.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 803      |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 163294   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.79e-08 |
# |    n_updates        | 40798    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 673      |
# |    ep_rew_mean      | 0.372    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 803      |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 165925   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.68e-08 |
# |    n_updates        | 41456    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 660      |
# |    ep_rew_mean      | 0.384    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 803      |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 167629   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.74e-10 |
# |    n_updates        | 41882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 643      |
# |    ep_rew_mean      | 0.401    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 803      |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 169046   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.35e-09 |
# |    n_updates        | 42236    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 617      |
# |    ep_rew_mean      | 0.426    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 803      |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 170035   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.94e-08 |
# |    n_updates        | 42483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 628      |
# |    ep_rew_mean      | 0.416    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 802      |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 172863   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.69e-09 |
# |    n_updates        | 43190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 626      |
# |    ep_rew_mean      | 0.418    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 803      |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 175941   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.48e-06 |
# |    n_updates        | 43960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 604      |
# |    ep_rew_mean      | 0.439    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 803      |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 176598   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37e-06 |
# |    n_updates        | 44124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 596      |
# |    ep_rew_mean      | 0.447    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 802      |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 178517   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.71e-10 |
# |    n_updates        | 44604    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 596      |
# |    ep_rew_mean      | 0.448    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 802      |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 182613   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.09e-08 |
# |    n_updates        | 45628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 581      |
# |    ep_rew_mean      | 0.463    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 802      |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 183753   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.59e-09 |
# |    n_updates        | 45913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 583      |
# |    ep_rew_mean      | 0.463    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 802      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 185529   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00842  |
# |    n_updates        | 46357    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 555      |
# |    ep_rew_mean      | 0.49     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 801      |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 186274   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.22e-06 |
# |    n_updates        | 46543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 546      |
# |    ep_rew_mean      | 0.498    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 801      |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 187696   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.43e-07 |
# |    n_updates        | 46898    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 533      |
# |    ep_rew_mean      | 0.512    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 801      |
# |    time_elapsed     | 237      |
# |    total_timesteps  | 190281   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45e-06 |
# |    n_updates        | 47545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 539      |
# |    ep_rew_mean      | 0.506    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 801      |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 193199   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.49e-07 |
# |    n_updates        | 48274    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 550      |
# |    ep_rew_mean      | 0.495    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 801      |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 195878   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.7e-08  |
# |    n_updates        | 48944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 546      |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 801      |
# |    time_elapsed     | 247      |
# |    total_timesteps  | 198101   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.78e-08 |
# |    n_updates        | 49500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 533      |
# |    ep_rew_mean      | 0.51     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 800      |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 199587   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.77e-07 |
# |    n_updates        | 49871    |
# ----------------------------------

# %%
model.save("./models/minigrid_empty_16x16_plain_dqn_1.pt")
# Out:
# /home/kobot/.local/lib/python3.10/site-packages/stable_baselines3/common/save_util.py:284: UserWarning: Path 'models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
